# %% [markdown]
# # Explore the data and model with plots

# %%
from tensorflow.keras.utils import plot_model
from utility_functions import plot_images
from sequential_api import get_data
from sequential_api import run_training
from sequential_api import get_model, get_data
from sequential_api import hyperparams

# %%
data_name = 'fashion_mnist'
train_X, train_y, test_X, test_y = get_data(data_name=data_name)
rows, columns = 6, 6
figure = plot_images(rows, columns, data_name, train_X, train_y)

# %% [markdown]
# # Plot model

# %%
model = get_model(hyperparams)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# layer_1 (Dense)              (None, 128)               100480
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# layer_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# last_layer (Dense)           (None, 10)                1290
# ...
# Total params: 119,306
# Trainable params: 118,794
# Non-trainable params: 512
# ...

# %%
plot_model(model)
